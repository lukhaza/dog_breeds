# %%
import torch
import torch.optim as optim
import torch.nn as nn
##import torch.functional as F
device = torch.device('cuda:0')
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from skimage import io,transform
import torchvision
import torchvision.transforms as transforms
from PIL import Image
from torch.autograd import Variable
import torch.nn.functional as F
batch_size = 38

# %%
full = pd.read_csv('labels.csv').reset_index()
doglist = pd.DataFrame(pd.read_csv('labels.csv')['breed'].unique(),columns=['breed']).reset_index()

# %%
pd.merge(full,doglist,how ='left',on = 'breed').to_csv('doglist.csv',index=False)

# %%
#pd.DataFrame(pd.read_csv('labels.csv')['breed'].unique(),columns=['dogs']).reset_index()['index'].iloc[4]

# %%
#pd.get_dummies(pd.read_csv('labels.csv')['breed']).iloc[5].valuejs

# %%
len(pd.read_csv('doglist.csv'))
# Out:
# 10222

# %%
class dogdata(Dataset):
    def __init__(self, dirroot,transform=None):
        self.labels = pd.read_csv('doglist.csv')
        self.transform = transform
        self.dirroot = dirroot
    def __len__(self):
        return len(self.labels)
    def __getitem__(self,idx):
        #self.labels['breed'][idx]
        fgimg = io.imread(self.dirroot+"\\"+self.labels['id'][idx]+'.jpg')
        if self.transform:
            fgimg = self.transform(fgimg)
        #return fgimg,self.labels['breed'][idx]
        #return fgimg,self.dogs['id'].iloc[idx].values
        return fgimg, self.labels['index_y'][idx]

# %%
scale_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(256),
    transforms.RandomCrop(224),
    transforms.ToTensor()
])

# %%
dogset = dogdata(dirroot = 'train\\train',transform = scale_transform)

# %%
trainloader = torch.utils.data.DataLoader(dogset, batch_size=batch_size, shuffle=True, num_workers=0)
testloader = torch.utils.data.DataLoader(dogset, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
to_pil = torchvision.transforms.ToPILImage()
img = to_pil(dogset[10][0])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x23F89F39668>

# %%
#for conv_layers and maxpool layer
##input_size-filter_size/stride + 1 = output_size

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3,10,kernel_size = 4, stride= 2)
        self.conv2 = nn.Conv2d(10,20,kernel_size = 7, stride= 2)
        self.conv3 = nn.Conv2d(20,40,kernel_size = 4, stride =2)
        self.mp = nn.MaxPool2d(3, stride = 1)
        self.fc = nn.Linear(19360,120) #22*22*40=19360
    def forward(self,x):
        x = F.relu(self.mp(self.conv1(x))) #output = 109 by 109 by 10
        x = F.relu(self.mp(self.conv2(x))) # output = 50 by 50 by 20
        x = F.relu(self.mp(self.conv3(x))) # output = 22 by 22 by 40
        #print(x.size())
        x = x.view(batch_size,-1)
        #print(x.size())
        x= self.fc(x)
        return F.log_softmax(x)

# %%
model = Net().cuda()
optimizer = optim.SGD(model.parameters(),lr = 0.015, momentum=0.5)

# %%
def train():
    model.train()
    for batch_idx, (data, target) in enumerate(trainloader):
        data = Variable(data).cuda()
        target = Variable(target).cuda()
        target = target.type(torch.cuda.LongTensor)
        #print(target)
        #target = torch.cuda.LongTensor(target)
        optimizer.zero_grad()
        output = model(data)
        #target = target.view(-1,1)

        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in testloader:
        data, target = Variable(data, volatile=True).cuda(), Variable(target).cuda()
        target = target.type(torch.cuda.LongTensor)
        output = model(data)
        # sum up batch loss
        test_loss += F.nll_loss(output, target, size_average=False).data[0]
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
    test_loss /= len(testloader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(testloader.dataset),
        100. * correct / len(testloader.dataset)))

# %%
for epoch in range(1, 50):
    train()
    test()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-66-b3d021833f90> in <module>()
#       1 for epoch in range(1, 50):
# ----> 2     train()
#       3     test()
#
# <ipython-input-62-8883f7b9f7ea> in train()
#       2     model.train()
#       3     for batch_idx, (data, target) in enumerate(trainloader):
# ----> 4         data = Variable(data).cuda()
#       5         target = Variable(target).cuda()
#       6         target = target.type(torch.cuda.LongTensor)
#
# RuntimeError: cuda runtime error (2) : out of memory at c:\programdata\miniconda3\conda-bld\pytorch_1524543037166\work\aten\src\thc\generic/THCStorage.cu:58

# %%
for batch_idx, (data, target) in enumerate(trainloader):
        print(target)
        break
# Out:
# tensor([   2,   79,   20,   64,   63,  103,  112,   96,    2,  104,
#           85,   59,   46,   96,   83,   52,   14,   90,   98,  112,
#          103,   43,   42,   37,   91,    5,  111,   70,   17,   43,
#           85,   62,    1,   33,  105,   67,   47,   69])

# %%
happy = io.imread('happy.jpg')

# %%
happy = torch.tensor(happy,device = device)
happy = scale_transform(happy)

# %%
happy.unsqueeze_(0)
happy =  Variable(happy).cuda()
out = model(happy)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-65789969bcc8> in <module>()
#       1 happy.unsqueeze_(0)
#       2 happy =  Variable(happy).cuda()
# ----> 3 out = model(happy)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# <ipython-input-13-e040e827a4f3> in forward(self, x)
#       8         self.fc = nn.Linear(19360,120) #22*22*40=19360
#       9     def forward(self,x):
# ---> 10         x = F.relu(self.mp(self.conv1(x))) #output = 109 by 109 by 10
#      11         x = F.relu(self.mp(self.conv2(x))) # output = 50 by 50 by 20
#      12         x = F.relu(self.mp(self.conv3(x))) # output = 22 by 22 by 40
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: expected stride to be a single integer value or a list of 3 values to match the convolution dimensions, but got stride=[2, 2]
