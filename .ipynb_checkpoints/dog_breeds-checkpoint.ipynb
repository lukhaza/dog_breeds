# %%
import torch
import torch.optim as optim
import torch.nn as nn
##import torch.functional as F
device = torch.device('cuda:0')
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from skimage import io,transform
import torchvision
import torchvision.transforms as transforms
from PIL import Image
from torch.autograd import Variable
import torch.nn.functional as F
batch_size = 38

# %%
full = pd.read_csv('labels.csv').reset_index()
doglist = pd.DataFrame(pd.read_csv('labels.csv')['breed'].unique(),columns=['breed']).reset_index()

# %%
pd.merge(full,doglist,how ='left',on = 'breed').to_csv('doglist.csv',index=False)

# %%
len(pd.read_csv('doglist.csv'))
# Out:
# 10222

# %%
class dogdata(Dataset):
    def __init__(self, dirroot,transform=None):
        self.labels = pd.read_csv('doglist.csv')
        self.transform = transform
        self.dirroot = dirroot
    def __len__(self):
        return len(self.labels)
    def __getitem__(self,idx):
        #self.labels['breed'][idx]
        fgimg = io.imread(self.dirroot+"\\"+self.labels['id'][idx]+'.jpg')
        if self.transform:
            fgimg = self.transform(fgimg)
        #return fgimg,self.labels['breed'][idx]
        #return fgimg,self.dogs['id'].iloc[idx].values
        return fgimg, self.labels['index_y'][idx]

# %%
scale_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(256),
    transforms.RandomCrop(224),
    transforms.ToTensor()
])

# %%
dogset = dogdata(dirroot = 'train\\train',transform = scale_transform)

# %%
trainloader = torch.utils.data.DataLoader(dogset, batch_size=batch_size, shuffle=True, num_workers=0)
testloader = torch.utils.data.DataLoader(dogset, batch_size=batch_size, shuffle=True, num_workers=0)

# %%
to_pil = torchvision.transforms.ToPILImage()
img = to_pil(dogset[12][0])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2B2699AF5F8>

# %%
#for conv_layers and maxpool layer
##input_size-filter_size/stride + 1 = output_size

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3,10,kernel_size = 4, stride= 2)
        self.conv2 = nn.Conv2d(10,20,kernel_size = 7, stride= 2)
        self.conv3 = nn.Conv2d(20,40,kernel_size = 4, stride =2)
        self.mp = nn.MaxPool2d(3, stride = 1)
        self.fc = nn.Linear(19360,120) #22*22*40=19360
    def forward(self,x):
        x = F.relu(self.mp(self.conv1(x))) #output = 109 by 109 by 10
        x = F.relu(self.mp(self.conv2(x))) # output = 50 by 50 by 20
        x = F.relu(self.mp(self.conv3(x))) # output = 22 by 22 by 40
        #print(x.size())
        x = x.view(batch_size,-1)
        #print(x.size())
        x= self.fc(x)
        return F.log_softmax(x)

# %%
model = Net().cuda()
optimizer = optim.SGD(model.parameters(),lr = 0.03, momentum=0.5)

# %%
def train():
    model.train()
    for batch_idx, (data, target) in enumerate(trainloader):
        data = Variable(data).cuda()
        target = Variable(target).cuda()
        target = target.type(torch.cuda.LongTensor)
        #print(target)
        #target = torch.cuda.LongTensor(target)
        optimizer.zero_grad()
        output = model(data)
        #target = target.view(-1,1)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in testloader:
        data, target = Variable(data, volatile=True).cuda(), Variable(target).cuda()
        target = target.type(torch.cuda.LongTensor)
        output = model(data)
        # sum up batch loss
        test_loss += F.nll_loss(output, target, size_average=False).data[0]
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        
    test_loss /= len(testloader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%) epoch: {}\n'.format(test_loss, correct, len(testloader.dataset),100. * correct / len(testloader.dataset),epoch))

# %%
for epoch in range(1, 15):
    train()
    test()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   # Remove the CWD from sys.path while we load stuff.
# Test set: Average loss: 4.7320, Accuracy: 186/10222 (1%) epoch: 1
#
#
# Test set: Average loss: 4.5287, Accuracy: 366/10222 (3%) epoch: 2
#
#
# Test set: Average loss: 4.4267, Accuracy: 530/10222 (5%) epoch: 3
#
#
# Test set: Average loss: 4.4771, Accuracy: 468/10222 (4%) epoch: 4
#
#
# Test set: Average loss: 4.1521, Accuracy: 948/10222 (9%) epoch: 5
#
#
# Test set: Average loss: 4.2043, Accuracy: 785/10222 (7%) epoch: 6
#
#
# Test set: Average loss: 3.9501, Accuracy: 1212/10222 (11%) epoch: 7
#
#
# Test set: Average loss: 3.7965, Accuracy: 1485/10222 (14%) epoch: 8
#
#
# Test set: Average loss: 3.7857, Accuracy: 1489/10222 (14%) epoch: 9
#
#
# Test set: Average loss: 3.6494, Accuracy: 1711/10222 (16%) epoch: 10
#
#
# Test set: Average loss: 3.5304, Accuracy: 1949/10222 (19%) epoch: 11
#
#
# Test set: Average loss: 3.4789, Accuracy: 2060/10222 (20%) epoch: 12
#
#
# Test set: Average loss: 3.4353, Accuracy: 2101/10222 (20%) epoch: 13
#
#
# Test set: Average loss: 3.5298, Accuracy: 2036/10222 (19%) epoch: 14

# %%
happy = io.imread('happy.jpg')

# %%
Image.open('happy.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x2B21F702240>

# %%
happy = torch.tensor(happy,device = device)
happy = scale_transform(happy)

# %%
happy.size()
# Out:
# torch.Size([3, 224, 224])

# %%
happy =  Variable(happy).cuda()
model.eval()
batch_size  = 1
with torch.no_grad():
      outputs = model(happy.unsqueeze_(0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
pd.read_csv('doglist.csv').loc[np.argmax(outputs).item()]['breed']
# Out:
# 'walker_hound'

# %% [markdown]
# ohk, so happy was classified as a walker hound when he is  in actual fact a Labrador Retriever :(
# oh,well !
